# %%
import numpy as np
import sympy
import matplotlib.pyplot as plt

# %%
def draw(M=(-2000,1500),
         r=15000,
         G=(8000,1500)):
    
    theta = np.linspace(0, 2*np.pi, 100)
    theta10 = np.linspace(0, 2*np.pi, 10)
    
    # Circle
    x_c = M[0] + r * np.cos(theta)
    y_c = M[1] + r * np.sin(theta)
    
    # Ellipse
    
    # Eccentricity and axes
    e = (G[0] - M[0])/r
    a = r/2
    b = ((r/2) ** 2 - ((G[0] - M[0])/2) ** 2) ** .5
    
    # Radius
    r_e = a*(1-e**2)/(1-e*np.cos(theta))
    
    x_e = M[0] + r_e * np.cos(theta)
    y_e = M[1] + r_e * np.sin(theta)
    
    # Alternatively
    x_e = (M[0] + G[0])/2 + a * np.cos(theta)
    y_e = (M[1] + G[1])/2 + b * np.sin(theta)
    
    # Tangents
#     x_t = (M[0] + G[0])/2 + a * (np.cos(theta) - np.sin(theta))
#     y_t = (M[1] + G[1])/2 + b * (np.sin(theta) + np.cos(theta))
    
    
    
    fig, ax = plt.subplots(figsize=(10,10))
    
    plt.plot(x_c, y_c)
    plt.plot(x_e, y_e)
    
#     for x0, x1, y0, y1 in zip(x_t, x_e, y_t, y_e):
#         plt.plot([x0, x1], [y0, y1])
        
    plt.scatter(*zip(M,G))
    
    ax.set_aspect('equal', 'box')

# %%
draw()

# %%
M=(-2000,1500)
r=15000
G=(8000,1500)

# %%
a,b,x_t,y_t,x_0,y_0,x_p,y_p,x,y,k = sympy.symbols('a b x_t y_t x_0 y_0 x_p y_p x y k')

# %%
# Ellipse equation
ell = (x - x_0)**2/a**2 + (y - y_0)**2/b**2 - 1 
ell
# Out:
# -1 + (y - y_0)**2/b**2 + (x - x_0)**2/a**2

# %%
# Line equation
line = {y:k*(x-x_p) + y_p}

# %%
# Values for num app
values = {x_0:(M[0] + G[0])/2,
        y_0:(M[1] + G[1])/2,
        a:r/2,
        b:((r/2) ** 2 - ((G[0] - M[0])/2) ** 2) ** .5}

# %%
# Polynomial in x to solve for tangent points
eq = sympy.Poly(ell.subs(line),x)

# %%
# Coefficients
A,B,C = eq.coeffs()

# %%
# Determinant
D = B**2 - 4*A*C

# %%
# Solve for k (if det is zero, there is only one solution, the tangential point)
sols_k = sympy.solve(D,k)

# %%
sols_k
# Out:
# [(-x_0*y_0 + x_0*y_p + x_p*y_0 - x_p*y_p - sqrt(-a**2*b**2 + a**2*y_0**2 - 2*a**2*y_0*y_p + a**2*y_p**2 + b**2*x_0**2 - 2*b**2*x_0*x_p + b**2*x_p**2))/(a**2 - x_0**2 + 2*x_0*x_p - x_p**2),
#  (-x_0*y_0 + x_0*y_p + x_p*y_0 - x_p*y_p + sqrt(-a**2*b**2 + a**2*y_0**2 - 2*a**2*y_0*y_p + a**2*y_p**2 + b**2*x_0**2 - 2*b**2*x_0*x_p + b**2*x_p**2))/(a**2 - x_0**2 + 2*x_0*x_p - x_p**2)]

# %%
sols_x = [sympy.solve(eq.subs({k:sol_k}),x) for sol_k in sols_k]

# %% [markdown]
# OK it seems to work. Now we will use the formula for the angle between two slopes m1 and m2. The condition $\widehat{RPS} > 45°$ is identical to $\tan(\theta) > 1$
#
# $$\tan(\theta) = \frac{m1−m2}{1+m1.m2}$$

# %%
m1, m2 = sols_k
tan_theta = (m1 - m2)/(1+m1*m2)

# Find the exact solutions for equality
sols_P = sympy.solve(sympy.simplify(tan_theta-1), (x_p, y_p))

# %%
sols_P
# Out:
# [(x_0 - sqrt(a**2 + 3*b**2 - y_0**2 + 2*y_0*y_p - y_p**2 - 2*sqrt(a**2*y_0**2 - 2*a**2*y_0*y_p + a**2*y_p**2 + 2*b**4 - b**2*y_0**2 + 2*b**2*y_0*y_p - b**2*y_p**2)),
#   y_p),
#  (x_0 + sqrt(a**2 + 3*b**2 - y_0**2 + 2*y_0*y_p - y_p**2 - 2*sqrt(a**2*y_0**2 - 2*a**2*y_0*y_p + a**2*y_p**2 + 2*b**4 - b**2*y_0**2 + 2*b**2*y_0*y_p - b**2*y_p**2)),
#   y_p),
#  (x_0 - sqrt(a**2 + 3*b**2 - y_0**2 + 2*y_0*y_p - y_p**2 + 2*sqrt(a**2*y_0**2 - 2*a**2*y_0*y_p + a**2*y_p**2 + 2*b**4 - b**2*y_0**2 + 2*b**2*y_0*y_p - b**2*y_p**2)),
#   y_p),
#  (x_0 + sqrt(a**2 + 3*b**2 - y_0**2 + 2*y_0*y_p - y_p**2 + 2*sqrt(a**2*y_0**2 - 2*a**2*y_0*y_p + a**2*y_p**2 + 2*b**4 - b**2*y_0**2 + 2*b**2*y_0*y_p - b**2*y_p**2)),
#   y_p)]

# %%
sols_P[2][0]
# Out:
# x_0 - sqrt(a**2 + 3*b**2 - y_0**2 + 2*y_0*y_p - y_p**2 + 2*sqrt(a**2*y_0**2 - 2*a**2*y_0*y_p + a**2*y_p**2 + 2*b**4 - b**2*y_0**2 + 2*b**2*y_0*y_p - b**2*y_p**2))

# %%
sols_P[1][0]
# Out:
# x_0 + sqrt(a**2 + 3*b**2 - y_0**2 + 2*y_0*y_p - y_p**2 - 2*sqrt(a**2*y_0**2 - 2*a**2*y_0*y_p + a**2*y_p**2 + 2*b**4 - b**2*y_0**2 + 2*b**2*y_0*y_p - b**2*y_p**2))

# %%
P = {x_p:15000,y_p:0}

x_t_list = [sol_x[0].subs(values).subs(P) for sol_x in sols_x]
y_t_list = [(y_0 - b * sympy.sqrt(1 - (x_t_list[0] - x_0) ** 2/a**2)).subs(values),
            (y_0 + b * sympy.sqrt(1 - (x_t_list[1] - x_0) ** 2/a**2)).subs(values)]

draw()
plt.plot([P[x_p],x_t_list[0]], [P[y_p],y_t_list[0]], color='g')
plt.plot([P[x_p],x_t_list[1]], [P[y_p],y_t_list[1]], color='g')

result=tan_theta.subs(values).subs(P)
print(result, result>1)
# Out:
# 1.82334342856413 True

# %%
y_p_list = np.linspace(-20000,25000,100)
draw()
for sol_P in sols_P:
    
    x_p_list = [sol_P[0].subs({y_p:v}).subs(values) for v in y_p_list]
    points = [(vx,vy) for vx,vy in zip(x_p_list,y_p_list) if vx.is_real]
    points = list(zip(*points))
    plt.plot(points[0],points[1], color='r')

# %%
[(vx,vy) for vx,vy in zip(x_p_list,y_p_list) if vx.is_real]
# Out:
# [(5253.74326140325, -17272.727272727272),
#  (7223.22820445034, -16818.181818181816),
#  (8495.26366583463, -16363.636363636364),
#  (9493.64011070900, -15909.090909090908),
#  (10331.1168515672, -15454.545454545454),
#  (11058.1055759619, -15000.0),
#  (11702.4281598957, -14545.454545454544),
#  (12281.4056989391, -14090.909090909092),
#  (12806.7097979681, -13636.363636363636),
#  (13286.6606166371, -13181.818181818182),
#  (13727.4452009694, -12727.272727272728),
#  (14133.8187418727, -12272.727272727272),
#  (14509.5344624653, -11818.181818181818),
#  (14857.6206686991, -11363.636363636364),
#  (15180.5667444682, -10909.090909090908),
#  (15480.4523505551, -10454.545454545454),
#  (15759.0398166791, -10000.0),
#  (16017.8418965821, -9545.454545454546),
#  (16258.1725673373, -9090.90909090909),
#  (16481.1858722993, -8636.363636363636),
#  (16687.9061480039, -8181.818181818182),
#  (16879.2519163938, -7727.272727272726),
#  (17056.0550282307, -7272.727272727272),
#  (17219.0761741361, -6818.181818181818),
#  (17369.0175542710, -6363.636363636364),
#  (17506.5332658711, -5909.090909090908),
#  (17632.2377982537, -5454.545454545454),
#  (17746.7128977091, -5000.0),
#  (17850.5129676391, -4545.454545454544),
#  (17944.1690952783, -4090.90909090909),
#  (18028.1917418876, -3636.363636363636),
#  (18103.0720977608, -3181.81818181818),
#  (18169.2820879727, -2727.272727272728),
#  (18227.2730218981, -2272.727272727272),
#  (18277.4729114540, -1818.1818181818162),
#  (18320.2825406494, -1363.636363636364),
#  (18356.0704501043, -909.0909090909081),
#  (18385.1670978323, -454.54545454545223),
#  (18407.8585593588, 0.0),
#  (18424.3802187890, 454.54545454545587),
#  (18434.9109577557, 909.0909090909081),
#  (18439.5683529366, 1363.636363636364),
#  (18438.4053335441, 1818.1818181818198),
#  (18431.4086278069, 2272.727272727272),
#  (18418.4991553737, 2727.272727272728),
#  (18399.5343257637, 3181.818181818184),
#  (18374.3120125212, 3636.363636363636),
#  (18342.5758180886, 4090.909090909092),
#  (18304.0211464169, 4545.454545454548),
#  (18258.3015669883, 5000.0),
#  (18205.0349801939, 5454.545454545456),
#  (18143.8091650152, 5909.090909090912),
#  (18074.1863861289, 6363.636363636364),
#  (17995.7068395088, 6818.18181818182),
#  (17907.8908077882, 7272.727272727272),
#  (17810.2394688781, 7727.272727272728),
#  (17702.2343487479, 8181.818181818184),
#  (17583.3354310422, 8636.363636363636),
#  (17452.9779339969, 9090.909090909092),
#  (17310.5677414079, 9545.454545454548),
#  (17155.4754312353, 10000.0),
#  (16987.0287833722, 10454.545454545456),
#  (16804.5035654598, 10909.090909090912),
#  (16607.1122876258, 11363.636363636364),
#  (16393.9904746826, 11818.18181818182),
#  (16164.1798127536, 12272.727272727272),
#  (15916.6072626750, 12727.272727272728),
#  (15650.0588569412, 13181.818181818184),
#  (15363.1463493635, 13636.36363636364),
#  (15054.2640664765, 14090.909090909096),
#  (14721.5320469385, 14545.454545454544),
#  (14362.7195526005, 15000.0),
#  (13975.1397541455, 15454.545454545456),
#  (13555.5008182572, 15909.090909090912),
#  (13099.6887364095, 16363.636363636368),
#  (12602.4388107745, 16818.181818181816),
#  (12056.8162729574, 17272.727272727272),
#  (11453.3490050768, 17727.272727272728),
#  (10778.4747177722, 18181.818181818184),
#  (10011.4909290954, 18636.36363636364),
#  (9117.73197515833, 19090.909090909096),
#  (8029.93290254179, 19545.454545454544),
#  (6574.98049478970, 20000.0)]

# %% [markdown]
# ## Annex
# Older stuff

# %%
# Slope of tangent at (x_t, y_t)
A = - (x_t - x_0)/(y_t - y_0) * b**2/a**2

# %%
# Intercept of tangent at (x, y)
B = - sols_k[0] * x + y
B
# Out:
# -x*(-x_0*y_0 + x_0*y_p + x_p*y_0 - x_p*y_p - sqrt(-a**2*b**2 + a**2*y_0**2 - 2*a**2*y_0*y_p + a**2*y_p**2 + b**2*x_0**2 - 2*b**2*x_0*x_p + b**2*x_p**2))/(a**2 - x_0**2 + 2*x_0*x_p - x_p**2) + y

# %%
B.subs(values).subs()
# Out:
# -x*(-x_p*y_p + 1500.0*x_p + 3000.0*y_p - 36742346.1417477*sqrt(2.31481481481481e-8*x_p**2 - 0.000138888888888889*x_p + 4.16666666666667e-8*y_p**2 - 0.000125*y_p - 1) - 4500000.0)/(-x_p**2 + 6000.0*x_p + 47250000.0) + y

# %%
points = [[(j,(A*x+B).subs(values).subs({x_t:i,x:j})) for j in np.linspace(-15000,15000,2)] for i in np.linspace(-2000,10000,13) ]
points = [list(zip(*point)) for point in points]

# %%
draw()
for point in points:
    plt.plot(*point)

# %%
h = sympy.sqrt(1 - (x_t - x_0) ** 2/a**2)
h
# Out:
# sqrt(1 - (-x_0 + x_t)**2/a**2)

# %%
A*x+B-y
# Out:
# b*sqrt(1 - (-x_0 + x_t)**2/a**2) - y + y_0 + b*x*(x_0 - x_t)/(a**2*sqrt(1 - (-x_0 + x_t)**2/a**2)) - b*x_t*(x_0 - x_t)/(a**2*sqrt(1 - (-x_0 + x_t)**2/a**2))

# %%
sols = sympy.solve((A*x+B-y),(x_t,y_t),simplify=False,rational=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\.conda\envs\euler\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     461         try:
# --> 462             return self._assumptions[fact]
#     463         except KeyError:
#
# KeyError: 'zero'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\.conda\envs\euler\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     461         try:
# --> 462             return self._assumptions[fact]
#     463         except KeyError:
#
# KeyError: 'finite'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23608/4273749070.py in <module>
# ----> 1 sols = sympy.solve((A*x+B-y),(x_t,y_t),simplify=False,rational=False)
#
# ~\.conda\envs\euler\lib\site-packages\sympy\solvers\solvers.py in solve(f, *symbols, **flags)
#    1093     ###########################################################################
#    1094     if bare_f:
# -> 1095         solution = _solve(f[0], *symbols, **flags)
#    1096     else:
#    1097         solution = _solve_system(f, symbols, **flags)
#
# ~\.conda\envs\euler\lib\site-packages\sympy\solvers\solvers.py in _solve(f, *symbols, **flags)
#    1351         for s in failed:
#    1352             try:
# -> 1353                 soln = _solve(f, s, **flags)
#    1354                 for sol in soln:
#    1355                     if got_s and any([ss in sol.free_symbols for ss in got_s]):
#
# ~\.conda\envs\euler\lib\site-packages\sympy\solvers\solvers.py in _solve(f, *symbols, **flags)
#    1684                 else:
#    1685                     try:
# -> 1686                         rv = set(_solve(eq, symbol, **flags))
#    1687                     except NotImplementedError:
#    1688                         rv = None
#
# ~\.conda\envs\euler\lib\site-packages\sympy\solvers\solvers.py in _solve(f, *symbols, **flags)
#    1389             # in any factor to zero
#    1390             dens = flags.get('_denominators', _simple_dens(f, symbols))
# -> 1391             result = [s for s in result if
#    1392                 all(not checksol(den, {symbol: s}, **flags) for den in
#    1393                 dens)]
#
# ~\.conda\envs\euler\lib\site-packages\sympy\solvers\solvers.py in <listcomp>(.0)
#    1390             dens = flags.get('_denominators', _simple_dens(f, symbols))
#    1391             result = [s for s in result if
# -> 1392                 all(not checksol(den, {symbol: s}, **flags) for den in
#    1393                 dens)]
#    1394         # set flags for quick exit at end; solutions for each
#
# ~\.conda\envs\euler\lib\site-packages\sympy\solvers\solvers.py in <genexpr>(.0)
#    1390             dens = flags.get('_denominators', _simple_dens(f, symbols))
#    1391             result = [s for s in result if
# -> 1392                 all(not checksol(den, {symbol: s}, **flags) for den in
#    1393                 dens)]
#    1394         # set flags for quick exit at end; solutions for each
#
# ~\.conda\envs\euler\lib\site-packages\sympy\solvers\solvers.py in checksol(f, symbol, sol, **flags)
#     315             # start over without the failed expanded form, possibly
#     316             # with a simplified solution
# --> 317             val = simplify(f.subs(sol))
#     318             if flags.get('force', True):
#     319                 val, reps = posify(val)
#
# ~\.conda\envs\euler\lib\site-packages\sympy\simplify\simplify.py in simplify(expr, ratio, measure, rational, inverse, doit, **kwargs)
#     604     # do deep simplification
#     605     handled = Add, Mul, Pow, ExpBase
# --> 606     expr = expr.replace(
#     607         # here, checking for x.args is not enough because Basic has
#     608         # args but Basic does not always play well with replace, e.g.
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\basic.py in replace(self, query, value, map, simultaneous, exact)
#    1496             return expr
#    1497
# -> 1498         rv = walk(self, rec_replace)
#    1499         return (rv, mapping) if map else rv
#    1500
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\basic.py in walk(rv, F)
#    1470             if args is not None:
#    1471                 if args:
# -> 1472                     newargs = tuple([walk(a, F) for a in args])
#    1473                     if args != newargs:
#    1474                         rv = rv.func(*newargs)
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\basic.py in <listcomp>(.0)
#    1470             if args is not None:
#    1471                 if args:
# -> 1472                     newargs = tuple([walk(a, F) for a in args])
#    1473                     if args != newargs:
#    1474                         rv = rv.func(*newargs)
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\basic.py in walk(rv, F)
#    1470             if args is not None:
#    1471                 if args:
# -> 1472                     newargs = tuple([walk(a, F) for a in args])
#    1473                     if args != newargs:
#    1474                         rv = rv.func(*newargs)
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\basic.py in <listcomp>(.0)
#    1470             if args is not None:
#    1471                 if args:
# -> 1472                     newargs = tuple([walk(a, F) for a in args])
#    1473                     if args != newargs:
#    1474                         rv = rv.func(*newargs)
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\basic.py in walk(rv, F)
#    1470             if args is not None:
#    1471                 if args:
# -> 1472                     newargs = tuple([walk(a, F) for a in args])
#    1473                     if args != newargs:
#    1474                         rv = rv.func(*newargs)
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\basic.py in <listcomp>(.0)
#    1470             if args is not None:
#    1471                 if args:
# -> 1472                     newargs = tuple([walk(a, F) for a in args])
#    1473                     if args != newargs:
#    1474                         rv = rv.func(*newargs)
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\basic.py in walk(rv, F)
#    1470             if args is not None:
#    1471                 if args:
# -> 1472                     newargs = tuple([walk(a, F) for a in args])
#    1473                     if args != newargs:
#    1474                         rv = rv.func(*newargs)
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\basic.py in <listcomp>(.0)
#    1470             if args is not None:
#    1471                 if args:
# -> 1472                     newargs = tuple([walk(a, F) for a in args])
#    1473                     if args != newargs:
#    1474                         rv = rv.func(*newargs)
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\basic.py in walk(rv, F)
#    1470             if args is not None:
#    1471                 if args:
# -> 1472                     newargs = tuple([walk(a, F) for a in args])
#    1473                     if args != newargs:
#    1474                         rv = rv.func(*newargs)
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\basic.py in <listcomp>(.0)
#    1470             if args is not None:
#    1471                 if args:
# -> 1472                     newargs = tuple([walk(a, F) for a in args])
#    1473                     if args != newargs:
#    1474                         rv = rv.func(*newargs)
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\basic.py in walk(rv, F)
#    1480                                 if rv == e and e != newargs[i]:
#    1481                                     return rv
# -> 1482                 rv = F(rv)
#    1483             return rv
#    1484
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\basic.py in rec_replace(expr)
#    1489             result = _query(expr)
#    1490             if result or result == {}:
# -> 1491                 v = _value(expr, result)
#    1492                 if v is not None and v != expr:
#    1493                     if map:
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\basic.py in <lambda>(expr, result)
#    1454
#    1455             if callable(value):
# -> 1456                 _value = lambda expr, result: value(expr)
#    1457             else:
#    1458                 raise TypeError(
#
# ~\.conda\envs\euler\lib\site-packages\sympy\simplify\simplify.py in <lambda>(x)
#     612         lambda x: isinstance(x, Expr) and x.args and not isinstance(
#     613             x, handled),
# --> 614         lambda x: x.func(*[simplify(i, **kwargs) for i in x.args]),
#     615         simultaneous=False)
#     616     if not isinstance(expr, handled):
#
# ~\.conda\envs\euler\lib\site-packages\sympy\simplify\simplify.py in <listcomp>(.0)
#     612         lambda x: isinstance(x, Expr) and x.args and not isinstance(
#     613             x, handled),
# --> 614         lambda x: x.func(*[simplify(i, **kwargs) for i in x.args]),
#     615         simultaneous=False)
#     616     if not isinstance(expr, handled):
#
# ~\.conda\envs\euler\lib\site-packages\sympy\simplify\simplify.py in simplify(expr, ratio, measure, rational, inverse, doit, **kwargs)
#     590     _eval_simplify = getattr(expr, '_eval_simplify', None)
#     591     if _eval_simplify is not None:
# --> 592         return _eval_simplify(**kwargs)
#     593
#     594     original_expr = expr = collect_abs(signsimp(expr))
#
# ~\.conda\envs\euler\lib\site-packages\sympy\functions\elementary\piecewise.py in _eval_simplify(self, **kwargs)
#      56
#      57     def _eval_simplify(self, **kwargs):
# ---> 58         return self.func(*[a.simplify(**kwargs) for a in self.args])
#      59
#      60 class Piecewise(Function):
#
# ~\.conda\envs\euler\lib\site-packages\sympy\functions\elementary\piecewise.py in <listcomp>(.0)
#      56
#      57     def _eval_simplify(self, **kwargs):
# ---> 58         return self.func(*[a.simplify(**kwargs) for a in self.args])
#      59
#      60 class Piecewise(Function):
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\basic.py in simplify(self, **kwargs)
#    1674         """See the simplify function in sympy.simplify"""
#    1675         from sympy.simplify import simplify
# -> 1676         return simplify(self, **kwargs)
#    1677
#    1678     def refine(self, assumption=True):
#
# ~\.conda\envs\euler\lib\site-packages\sympy\simplify\simplify.py in simplify(expr, ratio, measure, rational, inverse, doit, **kwargs)
#     634     expr = Mul(*powsimp(expr).as_content_primitive())
#     635     _e = cancel(expr)
# --> 636     expr1 = shorter(_e, _mexpand(_e).cancel())  # issue 6829
#     637     expr2 = shorter(together(expr, deep=True), together(expr1, deep=True))
#     638
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\expr.py in cancel(self, *gens, **args)
#    3729         """See the cancel function in sympy.polys"""
#    3730         from sympy.polys import cancel
# -> 3731         return cancel(self, *gens, **args)
#    3732
#    3733     def invert(self, g, *gens, **args):
#
# ~\.conda\envs\euler\lib\site-packages\sympy\polys\polytools.py in cancel(f, *gens, **args)
#    6680         if f.is_Number or isinstance(f, Relational) or not isinstance(f, Expr):
#    6681             return f
# -> 6682         f = factor_terms(f, radical=True)
#    6683         p, q = f.as_numer_denom()
#    6684
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in factor_terms(expr, radical, clear, fraction, sign)
#    1272         return rv
#    1273     expr = sympify(expr)
# -> 1274     return do(expr)
#    1275
#    1276
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in do(expr)
#    1247         cont, p = expr.as_content_primitive(radical=radical, clear=clear)
#    1248         if p.is_Add:
# -> 1249             list_args = [do(a) for a in Add.make_args(p)]
#    1250             # get a common negative (if there) which gcd_terms does not remove
#    1251             if all(a.as_coeff_Mul()[0].extract_multiplicatively(-1) is not None
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in <listcomp>(.0)
#    1247         cont, p = expr.as_content_primitive(radical=radical, clear=clear)
#    1248         if p.is_Add:
# -> 1249             list_args = [do(a) for a in Add.make_args(p)]
#    1250             # get a common negative (if there) which gcd_terms does not remove
#    1251             if all(a.as_coeff_Mul()[0].extract_multiplicatively(-1) is not None
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in do(expr)
#    1268         elif p.args:
#    1269             p = p.func(
# -> 1270                 *[do(a) for a in p.args])
#    1271         rv = _keep_coeff(cont, p, clear=clear, sign=sign)
#    1272         return rv
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in <listcomp>(.0)
#    1268         elif p.args:
#    1269             p = p.func(
# -> 1270                 *[do(a) for a in p.args])
#    1271         rv = _keep_coeff(cont, p, clear=clear, sign=sign)
#    1272         return rv
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in do(expr)
#    1235                 is_iterable or not hasattr(expr, 'args_cnc'):
#    1236             args = expr.args
# -> 1237             newargs = tuple([do(i) for i in args])
#    1238             if newargs == args:
#    1239                 return expr
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in <listcomp>(.0)
#    1235                 is_iterable or not hasattr(expr, 'args_cnc'):
#    1236             args = expr.args
# -> 1237             newargs = tuple([do(i) for i in args])
#    1238             if newargs == args:
#    1239                 return expr
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in do(expr)
#    1247         cont, p = expr.as_content_primitive(radical=radical, clear=clear)
#    1248         if p.is_Add:
# -> 1249             list_args = [do(a) for a in Add.make_args(p)]
#    1250             # get a common negative (if there) which gcd_terms does not remove
#    1251             if all(a.as_coeff_Mul()[0].extract_multiplicatively(-1) is not None
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in <listcomp>(.0)
#    1247         cont, p = expr.as_content_primitive(radical=radical, clear=clear)
#    1248         if p.is_Add:
# -> 1249             list_args = [do(a) for a in Add.make_args(p)]
#    1250             # get a common negative (if there) which gcd_terms does not remove
#    1251             if all(a.as_coeff_Mul()[0].extract_multiplicatively(-1) is not None
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in do(expr)
#    1268         elif p.args:
#    1269             p = p.func(
# -> 1270                 *[do(a) for a in p.args])
#    1271         rv = _keep_coeff(cont, p, clear=clear, sign=sign)
#    1272         return rv
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in <listcomp>(.0)
#    1268         elif p.args:
#    1269             p = p.func(
# -> 1270                 *[do(a) for a in p.args])
#    1271         rv = _keep_coeff(cont, p, clear=clear, sign=sign)
#    1272         return rv
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in do(expr)
#    1235                 is_iterable or not hasattr(expr, 'args_cnc'):
#    1236             args = expr.args
# -> 1237             newargs = tuple([do(i) for i in args])
#    1238             if newargs == args:
#    1239                 return expr
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in <listcomp>(.0)
#    1235                 is_iterable or not hasattr(expr, 'args_cnc'):
#    1236             args = expr.args
# -> 1237             newargs = tuple([do(i) for i in args])
#    1238             if newargs == args:
#    1239                 return expr
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in do(expr)
#    1247         cont, p = expr.as_content_primitive(radical=radical, clear=clear)
#    1248         if p.is_Add:
# -> 1249             list_args = [do(a) for a in Add.make_args(p)]
#    1250             # get a common negative (if there) which gcd_terms does not remove
#    1251             if all(a.as_coeff_Mul()[0].extract_multiplicatively(-1) is not None
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in <listcomp>(.0)
#    1247         cont, p = expr.as_content_primitive(radical=radical, clear=clear)
#    1248         if p.is_Add:
# -> 1249             list_args = [do(a) for a in Add.make_args(p)]
#    1250             # get a common negative (if there) which gcd_terms does not remove
#    1251             if all(a.as_coeff_Mul()[0].extract_multiplicatively(-1) is not None
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in do(expr)
#    1268         elif p.args:
#    1269             p = p.func(
# -> 1270                 *[do(a) for a in p.args])
#    1271         rv = _keep_coeff(cont, p, clear=clear, sign=sign)
#    1272         return rv
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in <listcomp>(.0)
#    1268         elif p.args:
#    1269             p = p.func(
# -> 1270                 *[do(a) for a in p.args])
#    1271         rv = _keep_coeff(cont, p, clear=clear, sign=sign)
#    1272         return rv
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in do(expr)
#    1235                 is_iterable or not hasattr(expr, 'args_cnc'):
#    1236             args = expr.args
# -> 1237             newargs = tuple([do(i) for i in args])
#    1238             if newargs == args:
#    1239                 return expr
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in <listcomp>(.0)
#    1235                 is_iterable or not hasattr(expr, 'args_cnc'):
#    1236             args = expr.args
# -> 1237             newargs = tuple([do(i) for i in args])
#    1238             if newargs == args:
#    1239                 return expr
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in do(expr)
#    1247         cont, p = expr.as_content_primitive(radical=radical, clear=clear)
#    1248         if p.is_Add:
# -> 1249             list_args = [do(a) for a in Add.make_args(p)]
#    1250             # get a common negative (if there) which gcd_terms does not remove
#    1251             if all(a.as_coeff_Mul()[0].extract_multiplicatively(-1) is not None
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in <listcomp>(.0)
#    1247         cont, p = expr.as_content_primitive(radical=radical, clear=clear)
#    1248         if p.is_Add:
# -> 1249             list_args = [do(a) for a in Add.make_args(p)]
#    1250             # get a common negative (if there) which gcd_terms does not remove
#    1251             if all(a.as_coeff_Mul()[0].extract_multiplicatively(-1) is not None
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in do(expr)
#    1268         elif p.args:
#    1269             p = p.func(
# -> 1270                 *[do(a) for a in p.args])
#    1271         rv = _keep_coeff(cont, p, clear=clear, sign=sign)
#    1272         return rv
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in <listcomp>(.0)
#    1268         elif p.args:
#    1269             p = p.func(
# -> 1270                 *[do(a) for a in p.args])
#    1271         rv = _keep_coeff(cont, p, clear=clear, sign=sign)
#    1272         return rv
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in do(expr)
#    1235                 is_iterable or not hasattr(expr, 'args_cnc'):
#    1236             args = expr.args
# -> 1237             newargs = tuple([do(i) for i in args])
#    1238             if newargs == args:
#    1239                 return expr
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in <listcomp>(.0)
#    1235                 is_iterable or not hasattr(expr, 'args_cnc'):
#    1236             args = expr.args
# -> 1237             newargs = tuple([do(i) for i in args])
#    1238             if newargs == args:
#    1239                 return expr
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in do(expr)
#    1262             # rebuild p not worrying about the order which gcd_terms will fix
#    1263             p = Add._from_args(list_args)
# -> 1264             p = gcd_terms(p,
#    1265                 isprimitive=True,
#    1266                 clear=clear,
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in gcd_terms(terms, isprimitive, clear, fraction)
#    1073             terms = sympify(terms)
#    1074         terms, reps = mask(terms)
# -> 1075         cont, numer, denom = _gcd_terms(terms, isprimitive, fraction)
#    1076         numer = numer.xreplace(reps)
#    1077         coeff, factors = cont.as_coeff_Mul()
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in _gcd_terms(terms, isprimitive, fraction)
#     971                 numers.append(term.coeff*numer.as_expr())
#     972         else:
# --> 973             numers = [t.as_expr() for t in terms]
#     974             denom = Term(S.One).numer
#     975
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in <listcomp>(.0)
#     971                 numers.append(term.coeff*numer.as_expr())
#     972         else:
# --> 973             numers = [t.as_expr() for t in terms]
#     974             denom = Term(S.One).numer
#     975
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in as_expr(self)
#     858
#     859     def as_expr(self):  # Term
# --> 860         return self.coeff*(self.numer.as_expr()/self.denom.as_expr())
#     861
#     862     def mul(self, other):  # Term
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\decorators.py in _func(self, other)
#     264             if not isinstance(other, expectedcls):
#     265                 return retval
# --> 266             return func(self, other)
#     267
#     268         return _func
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\decorators.py in binary_op_wrapper(self, other)
#     134                     if f is not None:
#     135                         return f(self)
# --> 136             return func(self, other)
#     137         return binary_op_wrapper
#     138     return priority_decorator
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\expr.py in __truediv__(self, other)
#     265             return denom
#     266         else:
# --> 267             return Mul(self, denom)
#     268
#     269     @sympify_return([('other', 'Expr')], NotImplemented)
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      70         def wrapper(*args, **kwargs):
#      71             try:
# ---> 72                 retval = cfunc(*args, **kwargs)
#      73             except TypeError as e:
#      74                 if not e.args or not e.args[0].startswith('unhashable type:'):
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\operations.py in __new__(cls, evaluate, _sympify, *args)
#      83             return args[0]
#      84
# ---> 85         c_part, nc_part, order_symbols = cls.flatten(args)
#      86         is_commutative = not nc_part
#      87         obj = cls._from_args(c_part + nc_part, is_commutative)
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\mul.py in flatten(cls, seq)
#     264                 seq = [a, b]
#     265             assert not a is S.One
# --> 266             if not a.is_zero and a.is_Rational:
#     267                 r, b = b.as_coeff_Mul()
#     268                 if b.is_Add:
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     464             if self._assumptions is self.default_assumptions:
#     465                 self._assumptions = self.default_assumptions.copy()
# --> 466             return _ask(fact, self)
#     467
#     468     getit.func_name = as_property(fact)
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     519             continue
#     520         if pk in handler_map:
# --> 521             _ask(pk, obj)
#     522
#     523             # we might have found the value of fact
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     519             continue
#     520         if pk in handler_map:
# --> 521             _ask(pk, obj)
#     522
#     523             # we might have found the value of fact
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     519             continue
#     520         if pk in handler_map:
# --> 521             _ask(pk, obj)
#     522
#     523             # we might have found the value of fact
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     519             continue
#     520         if pk in handler_map:
# --> 521             _ask(pk, obj)
#     522
#     523             # we might have found the value of fact
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     519             continue
#     520         if pk in handler_map:
# --> 521             _ask(pk, obj)
#     522
#     523             # we might have found the value of fact
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     519             continue
#     520         if pk in handler_map:
# --> 521             _ask(pk, obj)
#     522
#     523             # we might have found the value of fact
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     507         pass
#     508     else:
# --> 509         a = evaluate(obj)
#     510         if a is not None:
#     511             assumptions.deduce_all_facts(((fact, a),))
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\expr.py in _eval_is_negative(self)
#     858
#     859     def _eval_is_negative(self):
# --> 860         finite = self.is_finite
#     861         if finite is False:
#     862             return False
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     464             if self._assumptions is self.default_assumptions:
#     465                 self._assumptions = self.default_assumptions.copy()
# --> 466             return _ask(fact, self)
#     467
#     468     getit.func_name = as_property(fact)
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     519             continue
#     520         if pk in handler_map:
# --> 521             _ask(pk, obj)
#     522
#     523             # we might have found the value of fact
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     507         pass
#     508     else:
# --> 509         a = evaluate(obj)
#     510         if a is not None:
#     511             assumptions.deduce_all_facts(((fact, a),))
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\mul.py in _eval_is_even(self)
#    1613             return fuzzy_not(self.is_odd)
#    1614
# -> 1615         n, d = fraction(self)
#    1616         if n.is_Integer and n.is_even:
#    1617             # if minimal power of 2 in den vs num is not
#
# ~\.conda\envs\euler\lib\site-packages\sympy\simplify\radsimp.py in fraction(expr, exact)
#    1111         else:
#    1112             numer.append(term)
# -> 1113     return Mul(*numer, evaluate=not exact), Mul(*denom, evaluate=not exact)
#    1114
#    1115
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      70         def wrapper(*args, **kwargs):
#      71             try:
# ---> 72                 retval = cfunc(*args, **kwargs)
#      73             except TypeError as e:
#      74                 if not e.args or not e.args[0].startswith('unhashable type:'):
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\operations.py in __new__(cls, evaluate, _sympify, *args)
#      83             return args[0]
#      84
# ---> 85         c_part, nc_part, order_symbols = cls.flatten(args)
#      86         is_commutative = not nc_part
#      87         obj = cls._from_args(c_part + nc_part, is_commutative)
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\mul.py in flatten(cls, seq)
#     689
#     690         # order commutative part canonically
# --> 691         _mulsort(c_part)
#     692
#     693         # current code expects coeff to be always in slot-0
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\mul.py in _mulsort(args)
#      29 def _mulsort(args):
#      30     # in-place sorting of args
# ---> 31     args.sort(key=_args_sortkey)
#      32
#      33
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\basic.py in compare(self, other)
#     210         n1 = self.__class__
#     211         n2 = other.__class__
# --> 212         c = (n1 > n2) - (n1 < n2)
#     213         if c:
#     214             return c
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\core.py in __gt__(cls, other)
#     100
#     101     def __gt__(cls, other):
# --> 102         if cls.__cmp__(other) == 1:
#     103             return True
#     104         return False
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\core.py in __cmp__(cls, other)
#      71         cls.__sympy__ = property(lambda self: True)
#      72
# ---> 73     def __cmp__(cls, other):
#      74         # If the other object is not a Basic subclass, then we are not equal to
#      75         # it.
#
# KeyboardInterrupt:

# %%
ell = {y_t:y_0 + b * sympy.sqrt(1 - (x_t - x_0) ** 2/a**2)}

# %%
[sol.subs(ell) for sol in sols[0]]

# %%
sympy.simplify(sols[0][0].subs(ell))
# Out:
# (b*x + b*x_0 - sqrt(b*(-4*a**2*b + 4*a**2*y*sqrt((a**2 - x_0**2 + 2*x_0*x_t - x_t**2)/a**2) - 4*a**2*y_0*sqrt((a**2 - x_0**2 + 2*x_0*x_t - x_t**2)/a**2) + b*x**2 - 2*b*x*x_0 + 5*b*x_0**2 - 8*b*x_0*x_t + 4*b*x_t**2)))/(2*b)

# %%
sympy.solve(sols[0][0].subs(ell)-x_t,x_t)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23608/1740111568.py in <module>
# ----> 1 sympy.solve(sols[0][0].subs(ell)-x_t,x_t)
#
# ~\.conda\envs\euler\lib\site-packages\sympy\solvers\solvers.py in solve(f, *symbols, **flags)
#    1093     ###########################################################################
#    1094     if bare_f:
# -> 1095         solution = _solve(f[0], *symbols, **flags)
#    1096     else:
#    1097         solution = _solve_system(f, symbols, **flags)
#
# ~\.conda\envs\euler\lib\site-packages\sympy\solvers\solvers.py in _solve(f, *symbols, **flags)
#    1724     if check:
#    1725         # keep only results if the check is not False
# -> 1726         result = [r for r in result if
#    1727                   checksol(f_num, {symbol: r}, **flags) is not False]
#    1728     return result
#
# ~\.conda\envs\euler\lib\site-packages\sympy\solvers\solvers.py in <listcomp>(.0)
#    1725         # keep only results if the check is not False
#    1726         result = [r for r in result if
# -> 1727                   checksol(f_num, {symbol: r}, **flags) is not False]
#    1728     return result
#    1729
#
# ~\.conda\envs\euler\lib\site-packages\sympy\solvers\solvers.py in checksol(f, symbol, sol, **flags)
#     315             # start over without the failed expanded form, possibly
#     316             # with a simplified solution
# --> 317             val = simplify(f.subs(sol))
#     318             if flags.get('force', True):
#     319                 val, reps = posify(val)
#
# ~\.conda\envs\euler\lib\site-packages\sympy\simplify\simplify.py in simplify(expr, ratio, measure, rational, inverse, doit, **kwargs)
#     634     expr = Mul(*powsimp(expr).as_content_primitive())
#     635     _e = cancel(expr)
# --> 636     expr1 = shorter(_e, _mexpand(_e).cancel())  # issue 6829
#     637     expr2 = shorter(together(expr, deep=True), together(expr1, deep=True))
#     638
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\expr.py in cancel(self, *gens, **args)
#    3729         """See the cancel function in sympy.polys"""
#    3730         from sympy.polys import cancel
# -> 3731         return cancel(self, *gens, **args)
#    3732
#    3733     def invert(self, g, *gens, **args):
#
# ~\.conda\envs\euler\lib\site-packages\sympy\polys\polytools.py in cancel(f, *gens, **args)
#    6680         if f.is_Number or isinstance(f, Relational) or not isinstance(f, Expr):
#    6681             return f
# -> 6682         f = factor_terms(f, radical=True)
#    6683         p, q = f.as_numer_denom()
#    6684
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in factor_terms(expr, radical, clear, fraction, sign)
#    1272         return rv
#    1273     expr = sympify(expr)
# -> 1274     return do(expr)
#    1275
#    1276
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in do(expr)
#    1247         cont, p = expr.as_content_primitive(radical=radical, clear=clear)
#    1248         if p.is_Add:
# -> 1249             list_args = [do(a) for a in Add.make_args(p)]
#    1250             # get a common negative (if there) which gcd_terms does not remove
#    1251             if all(a.as_coeff_Mul()[0].extract_multiplicatively(-1) is not None
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in <listcomp>(.0)
#    1247         cont, p = expr.as_content_primitive(radical=radical, clear=clear)
#    1248         if p.is_Add:
# -> 1249             list_args = [do(a) for a in Add.make_args(p)]
#    1250             # get a common negative (if there) which gcd_terms does not remove
#    1251             if all(a.as_coeff_Mul()[0].extract_multiplicatively(-1) is not None
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in do(expr)
#    1268         elif p.args:
#    1269             p = p.func(
# -> 1270                 *[do(a) for a in p.args])
#    1271         rv = _keep_coeff(cont, p, clear=clear, sign=sign)
#    1272         return rv
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in <listcomp>(.0)
#    1268         elif p.args:
#    1269             p = p.func(
# -> 1270                 *[do(a) for a in p.args])
#    1271         rv = _keep_coeff(cont, p, clear=clear, sign=sign)
#    1272         return rv
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in do(expr)
#    1235                 is_iterable or not hasattr(expr, 'args_cnc'):
#    1236             args = expr.args
# -> 1237             newargs = tuple([do(i) for i in args])
#    1238             if newargs == args:
#    1239                 return expr
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in <listcomp>(.0)
#    1235                 is_iterable or not hasattr(expr, 'args_cnc'):
#    1236             args = expr.args
# -> 1237             newargs = tuple([do(i) for i in args])
#    1238             if newargs == args:
#    1239                 return expr
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in do(expr)
#    1247         cont, p = expr.as_content_primitive(radical=radical, clear=clear)
#    1248         if p.is_Add:
# -> 1249             list_args = [do(a) for a in Add.make_args(p)]
#    1250             # get a common negative (if there) which gcd_terms does not remove
#    1251             if all(a.as_coeff_Mul()[0].extract_multiplicatively(-1) is not None
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in <listcomp>(.0)
#    1247         cont, p = expr.as_content_primitive(radical=radical, clear=clear)
#    1248         if p.is_Add:
# -> 1249             list_args = [do(a) for a in Add.make_args(p)]
#    1250             # get a common negative (if there) which gcd_terms does not remove
#    1251             if all(a.as_coeff_Mul()[0].extract_multiplicatively(-1) is not None
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in do(expr)
#    1268         elif p.args:
#    1269             p = p.func(
# -> 1270                 *[do(a) for a in p.args])
#    1271         rv = _keep_coeff(cont, p, clear=clear, sign=sign)
#    1272         return rv
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in <listcomp>(.0)
#    1268         elif p.args:
#    1269             p = p.func(
# -> 1270                 *[do(a) for a in p.args])
#    1271         rv = _keep_coeff(cont, p, clear=clear, sign=sign)
#    1272         return rv
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in do(expr)
#    1235                 is_iterable or not hasattr(expr, 'args_cnc'):
#    1236             args = expr.args
# -> 1237             newargs = tuple([do(i) for i in args])
#    1238             if newargs == args:
#    1239                 return expr
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in <listcomp>(.0)
#    1235                 is_iterable or not hasattr(expr, 'args_cnc'):
#    1236             args = expr.args
# -> 1237             newargs = tuple([do(i) for i in args])
#    1238             if newargs == args:
#    1239                 return expr
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in do(expr)
#    1247         cont, p = expr.as_content_primitive(radical=radical, clear=clear)
#    1248         if p.is_Add:
# -> 1249             list_args = [do(a) for a in Add.make_args(p)]
#    1250             # get a common negative (if there) which gcd_terms does not remove
#    1251             if all(a.as_coeff_Mul()[0].extract_multiplicatively(-1) is not None
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in <listcomp>(.0)
#    1247         cont, p = expr.as_content_primitive(radical=radical, clear=clear)
#    1248         if p.is_Add:
# -> 1249             list_args = [do(a) for a in Add.make_args(p)]
#    1250             # get a common negative (if there) which gcd_terms does not remove
#    1251             if all(a.as_coeff_Mul()[0].extract_multiplicatively(-1) is not None
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in do(expr)
#    1268         elif p.args:
#    1269             p = p.func(
# -> 1270                 *[do(a) for a in p.args])
#    1271         rv = _keep_coeff(cont, p, clear=clear, sign=sign)
#    1272         return rv
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in <listcomp>(.0)
#    1268         elif p.args:
#    1269             p = p.func(
# -> 1270                 *[do(a) for a in p.args])
#    1271         rv = _keep_coeff(cont, p, clear=clear, sign=sign)
#    1272         return rv
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in do(expr)
#    1235                 is_iterable or not hasattr(expr, 'args_cnc'):
#    1236             args = expr.args
# -> 1237             newargs = tuple([do(i) for i in args])
#    1238             if newargs == args:
#    1239                 return expr
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in <listcomp>(.0)
#    1235                 is_iterable or not hasattr(expr, 'args_cnc'):
#    1236             args = expr.args
# -> 1237             newargs = tuple([do(i) for i in args])
#    1238             if newargs == args:
#    1239                 return expr
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in do(expr)
#    1247         cont, p = expr.as_content_primitive(radical=radical, clear=clear)
#    1248         if p.is_Add:
# -> 1249             list_args = [do(a) for a in Add.make_args(p)]
#    1250             # get a common negative (if there) which gcd_terms does not remove
#    1251             if all(a.as_coeff_Mul()[0].extract_multiplicatively(-1) is not None
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in <listcomp>(.0)
#    1247         cont, p = expr.as_content_primitive(radical=radical, clear=clear)
#    1248         if p.is_Add:
# -> 1249             list_args = [do(a) for a in Add.make_args(p)]
#    1250             # get a common negative (if there) which gcd_terms does not remove
#    1251             if all(a.as_coeff_Mul()[0].extract_multiplicatively(-1) is not None
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\exprtools.py in do(expr)
#    1245                 fraction=fraction, sign=sign)
#    1246
# -> 1247         cont, p = expr.as_content_primitive(radical=radical, clear=clear)
#    1248         if p.is_Add:
#    1249             list_args = [do(a) for a in Add.make_args(p)]
#
# ~\.conda\envs\euler\lib\site-packages\sympy\core\mul.py in as_content_primitive(self, radical, clear)
#    2016             c, p = a.as_content_primitive(radical=radical, clear=clear)
#    2017             coef *= c
# -> 2018             if p is not S.One:
#    2019                 args.append(p)
#    2020         # don't use self._from_args here to reconstruct args
#
# KeyboardInterrupt:
